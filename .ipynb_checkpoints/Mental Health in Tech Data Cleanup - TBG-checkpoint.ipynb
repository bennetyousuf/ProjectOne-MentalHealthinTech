# %%
#Import Dependencies

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import scipy.stats as st
from scipy.stats import linregress
import time
from datetime import datetime

# %%
#import raw data csv

input_data_file = "../RAW DATA/SURVEY RAW DATA 2_CSV.CSV"

# Read in file and store in Pandas data frame
survey_data_df = pd.read_csv(input_data_file)
survey_data_df 

 


# ideal_cities_df = weather_df.loc[(weather_df["Max Temp"] > 70) & (weather_df["Max Temp"] < 80) & (weather_df["Cloudiness"] == 0) & (weather_df["Wind Speed"] <10), :]
# Out:
#       YEAR 1_SELF_EMPLOY 2_NUM_OF_EMPLOYEES 3_TECH_ORG  \
# 0     2017             0            100-500          1
# 1     2017             0            100-500          1
# 2     2017             0             25-Jun          1
# 3     2017             0     More than 1000          1
# 4     2017             1                NaN        NaN
# ...    ...           ...                ...        ...
# 1700  2020             0     More than 1000          0
# 1701  2020             0             26-100          1
# 1702  2020             0            100-500          1
# 1703  2020             0           500-1000          0
# 1704  2020             0           500-1000          1
#
#                    4_MH_BEN_PROVIDED 5_AWARE_OF_MH_BENEFITS  \
# 0                                 No                    Yes
# 1                                Yes                    Yes
# 2                       I don't know                     No
# 3                                Yes                    Yes
# 4                                NaN                    NaN
# ...                              ...                    ...
# 1700                              No                     No
# 1701                             Yes                    Yes
# 1702                    I don't know                     No
# 1703                             Yes                     No
# 1704  Not eligible for coverage / NA                    NaN
#
#      6_EMPLOY_FORMALLY_DISCUSS_MH 7_EMPLOY_OFFER_RESOURCES  \
# 0                              No             I don't know
# 1                              No                       No
# 2                    I don't know                       No
# 3                    I don't know             I don't know
# 4                             NaN                      NaN
# ...                           ...                      ...
# 1700                           No                       No
# 1701                          Yes                      Yes
# 1702                           No             I don't know
# 1703                          Yes                      Yes
# 1704                          Yes                       No
#
#      8_ANONIMITY_PROTECT 9_COMFORT_DISCUSS_SUPERVISOR  ...  \
# 0           I don't know                          Yes  ...
# 1           I don't know                        Maybe  ...
# 2                    Yes                          Yes  ...
# 3                    Yes                          Yes  ...
# 4                    NaN                          NaN  ...
# ...                  ...                          ...  ...
# 1700                  No                           No  ...
# 1701        I don't know                        Maybe  ...
# 1702        I don't know                        Maybe  ...
# 1703                 Yes                           No  ...
# 1704        I don't know                          Yes  ...
#
#      16_DIAGNOSED_MH_DISORDER  17_DISORDER_INTERFERE_WITH_WORK_WHEN_TREATED  \
# 0                         NaN                                     Sometimes
# 1                         NaN                          Not applicable to me
# 2                         Yes                                     Sometimes
# 3                         Yes                                     Sometimes
# 4                         NaN                                         Often
# ...                       ...                                           ...
# 1700                      NaN                                     Sometimes
# 1701                      NaN                                         Often
# 1702                      Yes                                     Sometimes
# 1703                      NaN                                        Rarely
# 1704                      NaN                          Not applicable to me
#
#       18_DISORDER_INTERFERE_WITH_WORK_WHEN_NOT_TREATED  \
# 0                                            Sometimes
# 1                                            Sometimes
# 2                                            Sometimes
# 3                                                Often
# 4                                            Sometimes
# ...                                                ...
# 1700                                             Often
# 1701                                             Often
# 1702                                             Often
# 1703                                         Sometimes
# 1704                              Not applicable to me
#
#      19_TECH_SUPPORT_EMPLOYEE_w_MH_DISORDER 20_AGE 21_GENDER  \
# 0                                       1.0   27.0    Female
# 1                                       2.0   31.0      male
# 2                                       1.0   36.0      male
# 3                                       2.0   22.0      Male
# 4                                       1.0   52.0    female
# ...                                     ...    ...       ...
# 1700                                    2.0   53.0      Male
# 1701                                    3.0   23.0         F
# 1702                                    3.0   34.0      Male
# 1703                                    3.0   43.0      Male
# 1704                                    4.0   37.0      male
#
#                     22_COUNTRY    23_STATE                     24_RACE  \
# 0               United Kingdom         NaN                         NaN
# 1               United Kingdom         NaN                         NaN
# 2     United States of America    Missouri                       White
# 3     United States of America  Washington                       White
# 4     United States of America    Illinois  More than one of the above
# ...                        ...         ...                         ...
# 1700  United States of America    New York                       Asian
# 1701               Philippines         NaN                         NaN
# 1702  United States of America   Tennessee                       White
# 1703                    Canada         NaN                         NaN
# 1704               Netherlands         NaN                         NaN
#
#                   25_COUNTRY_2
# 0               United Kingdom
# 1               United Kingdom
# 2     United States of America
# 3     United States of America
# 4     United States of America
# ...                        ...
# 1700  United States of America
# 1701               Philippines
# 1702  United States of America
# 1703                    Canada
# 1704               Netherlands
#
# [1705 rows x 26 columns]

# %%
#Of responses from the Survey 864 out of 1705 particpants in the last 4 years were for employers in the tech industry
# Filter out survey responses for individuals that were not employees of tech organizations (Survey question 3)
#tech_mental_health will be the data frame that we use for ongoing anaylis.

tech_mental_health = survey_data_df.loc[survey_data_df["3_TECH_ORG"]=="1"]
tech_mental_health
# Out:
#       YEAR 1_SELF_EMPLOY 2_NUM_OF_EMPLOYEES 3_TECH_ORG  \
# 0     2017             0            100-500          1
# 1     2017             0            100-500          1
# 2     2017             0             25-Jun          1
# 3     2017             0     More than 1000          1
# 5     2017             0            100-500          1
# ...    ...           ...                ...        ...
# 1698  2020             0             26-100          1
# 1699  2020             0     More than 1000          1
# 1701  2020             0             26-100          1
# 1702  2020             0            100-500          1
# 1704  2020             0           500-1000          1
#
#                    4_MH_BEN_PROVIDED 5_AWARE_OF_MH_BENEFITS  \
# 0                                 No                    Yes
# 1                                Yes                    Yes
# 2                       I don't know                     No
# 3                                Yes                    Yes
# 5                                Yes                     No
# ...                              ...                    ...
# 1698                             Yes                    Yes
# 1699                    I don't know                     No
# 1701                             Yes                    Yes
# 1702                    I don't know                     No
# 1704  Not eligible for coverage / NA                    NaN
#
#      6_EMPLOY_FORMALLY_DISCUSS_MH 7_EMPLOY_OFFER_RESOURCES  \
# 0                              No             I don't know
# 1                              No                       No
# 2                    I don't know                       No
# 3                    I don't know             I don't know
# 5                              No             I don't know
# ...                           ...                      ...
# 1698                          Yes                      Yes
# 1699                 I don't know             I don't know
# 1701                          Yes                      Yes
# 1702                           No             I don't know
# 1704                          Yes                       No
#
#      8_ANONIMITY_PROTECT 9_COMFORT_DISCUSS_SUPERVISOR  ...  \
# 0           I don't know                          Yes  ...
# 1           I don't know                        Maybe  ...
# 2                    Yes                          Yes  ...
# 3                    Yes                          Yes  ...
# 5                    Yes                        Maybe  ...
# ...                  ...                          ...  ...
# 1698                  No                           No  ...
# 1699        I don't know                           No  ...
# 1701        I don't know                        Maybe  ...
# 1702        I don't know                        Maybe  ...
# 1704        I don't know                          Yes  ...
#
#      16_DIAGNOSED_MH_DISORDER  17_DISORDER_INTERFERE_WITH_WORK_WHEN_TREATED  \
# 0                         NaN                                     Sometimes
# 1                         NaN                          Not applicable to me
# 2                         Yes                                     Sometimes
# 3                         Yes                                     Sometimes
# 5                         NaN                                        Rarely
# ...                       ...                                           ...
# 1698                      Yes                                     Sometimes
# 1699                      NaN                                         Often
# 1701                      NaN                                         Often
# 1702                      Yes                                     Sometimes
# 1704                      NaN                          Not applicable to me
#
#       18_DISORDER_INTERFERE_WITH_WORK_WHEN_NOT_TREATED  \
# 0                                            Sometimes
# 1                                            Sometimes
# 2                                            Sometimes
# 3                                                Often
# 5                                 Not applicable to me
# ...                                                ...
# 1698                                             Often
# 1699                                             Often
# 1701                                             Often
# 1702                                             Often
# 1704                              Not applicable to me
#
#      19_TECH_SUPPORT_EMPLOYEE_w_MH_DISORDER 20_AGE 21_GENDER  \
# 0                                       1.0   27.0    Female
# 1                                       2.0   31.0      male
# 2                                       1.0   36.0      male
# 3                                       2.0   22.0      Male
# 5                                       2.0   30.0      male
# ...                                     ...    ...       ...
# 1698                                    2.0   40.0    Female
# 1699                                    2.0   31.0      male
# 1701                                    3.0   23.0         F
# 1702                                    3.0   34.0      Male
# 1704                                    4.0   37.0      male
#
#                     22_COUNTRY    23_STATE 24_RACE              25_COUNTRY_2
# 0               United Kingdom         NaN     NaN            United Kingdom
# 1               United Kingdom         NaN     NaN            United Kingdom
# 2     United States of America    Missouri   White  United States of America
# 3     United States of America  Washington   White  United States of America
# 5     United States of America  California   White  United States of America
# ...                        ...         ...     ...                       ...
# 1698            United Kingdom         NaN     NaN            United Kingdom
# 1699                     India         NaN     NaN                     India
# 1701               Philippines         NaN     NaN               Philippines
# 1702  United States of America   Tennessee   White  United States of America
# 1704               Netherlands         NaN     NaN               Netherlands
#
# [864 rows x 26 columns]

# %%
tech_mental_health.to_csv('Scrubbed_Raw_data')

# %%
#1..#Analysis of Question 4 - How many employers provide mental health benefits
#What was the breakdown of answers for this quesion of the 864 parcticipants that work in tech
#Used to see if responses that were similar in sentiment but wrere free text by participants
mental_health_benefits_responses= tech_mental_health["4_MH_BEN_PROVIDED"].value_counts()
mental_health_benefits_responses
# Out:
# Yes                               476
# I don't know                      220
# No                                128
# Not eligible for coverage / NA     40
# Name: 4_MH_BEN_PROVIDED, dtype: int64

# %%
#1. Analysis of Question 4 - How many employers provide mental health benefits across all 4 years
#How many employees answered this question - 1463
employers_who_do_provide_mental_health_benefits= tech_mental_health.loc[tech_mental_health["4_MH_BEN_PROVIDED"]=="Yes"]
employers_who_do_provide_mental_health_benefits
# Out:
#       YEAR 1_SELF_EMPLOY 2_NUM_OF_EMPLOYEES 3_TECH_ORG 4_MH_BEN_PROVIDED  \
# 1     2017             0            100-500          1               Yes
# 3     2017             0     More than 1000          1               Yes
# 5     2017             0            100-500          1               Yes
# 6     2017             0              44372          1               Yes
# 7     2017             0             26-100          1               Yes
# ...    ...           ...                ...        ...               ...
# 1690  2020             0     More than 1000          1               Yes
# 1693  2020             0             26-100          1               Yes
# 1696  2020             0     More than 1000          1               Yes
# 1698  2020             0             26-100          1               Yes
# 1701  2020             0             26-100          1               Yes
#
#      5_AWARE_OF_MH_BENEFITS 6_EMPLOY_FORMALLY_DISCUSS_MH  \
# 1                       Yes                           No
# 3                       Yes                 I don't know
# 5                        No                           No
# 6                       Yes                           No
# 7                        No                           No
# ...                     ...                          ...
# 1690                     No                           No
# 1693                     No                          Yes
# 1696                    Yes                          Yes
# 1698                    Yes                          Yes
# 1701                    Yes                          Yes
#
#      7_EMPLOY_OFFER_RESOURCES 8_ANONIMITY_PROTECT  \
# 1                          No        I don't know
# 3                I don't know                 Yes
# 5                I don't know                 Yes
# 6                          No                 Yes
# 7                          No        I don't know
# ...                       ...                 ...
# 1690             I don't know        I don't know
# 1693                      Yes        I don't know
# 1696                      Yes                 Yes
# 1698                      Yes                  No
# 1701                      Yes        I don't know
#
#      9_COMFORT_DISCUSS_SUPERVISOR  ... 16_DIAGNOSED_MH_DISORDER  \
# 1                           Maybe  ...                      NaN
# 3                             Yes  ...                      Yes
# 5                           Maybe  ...                      NaN
# 6                             Yes  ...                      Yes
# 7                             Yes  ...                      NaN
# ...                           ...  ...                      ...
# 1690                           No  ...                      NaN
# 1693                          Yes  ...                      Yes
# 1696                        Maybe  ...                      NaN
# 1698                           No  ...                      Yes
# 1701                        Maybe  ...                      NaN
#
#       17_DISORDER_INTERFERE_WITH_WORK_WHEN_TREATED  \
# 1                             Not applicable to me
# 3                                        Sometimes
# 5                                           Rarely
# 6                                           Rarely
# 7                             Not applicable to me
# ...                                            ...
# 1690                          Not applicable to me
# 1693                                         Often
# 1696                          Not applicable to me
# 1698                                     Sometimes
# 1701                                         Often
#
#       18_DISORDER_INTERFERE_WITH_WORK_WHEN_NOT_TREATED  \
# 1                                            Sometimes
# 3                                                Often
# 5                                 Not applicable to me
# 6                                                Often
# 7                                 Not applicable to me
# ...                                                ...
# 1690                              Not applicable to me
# 1693                                             Often
# 1696                              Not applicable to me
# 1698                                             Often
# 1701                                             Often
#
#      19_TECH_SUPPORT_EMPLOYEE_w_MH_DISORDER 20_AGE 21_GENDER  \
# 1                                       2.0   31.0      male
# 3                                       2.0   22.0      Male
# 5                                       2.0   30.0      male
# 6                                       2.0   36.0         F
# 7                                       2.0   38.0    Female
# ...                                     ...    ...       ...
# 1690                                    2.0   21.0      Male
# 1693                                    2.0   39.0      Male
# 1696                                    2.0   39.0      Male
# 1698                                    2.0   40.0    Female
# 1701                                    3.0   23.0         F
#
#                     22_COUNTRY       23_STATE 24_RACE  \
# 1               United Kingdom            NaN     NaN
# 3     United States of America     Washington   White
# 5     United States of America     California   White
# 6     United States of America     Washington   Asian
# 7     United States of America        Georgia   White
# ...                        ...            ...     ...
# 1690                   Ireland            NaN     NaN
# 1693  United States of America       Colorado   White
# 1696  United States of America  Massachusetts   White
# 1698            United Kingdom            NaN     NaN
# 1701               Philippines            NaN     NaN
#
#                   25_COUNTRY_2
# 1               United Kingdom
# 3     United States of America
# 5     United States of America
# 6     United States of America
# 7     United States of America
# ...                        ...
# 1690                   Ireland
# 1693  United States of America
# 1696  United States of America
# 1698            United Kingdom
# 1701               Philippines
#
# [476 rows x 26 columns]

# %%
# 1.Analysis of Question 4 - How many employers provide mental health benefits
#What was the breakdown of answers for this quesion of the 1463 that did answer aross all 4 years

employers_who_provide_mental_health_benefits= tech_mental_health["4_MH_BEN_PROVIDED"].value_counts()
employers_who_provide_mental_health_benefits.plot(kind ="pie", ylabel = "", title ="Employers Who Provide Mental Health Benefits",autopct="%1.1f%%")
# Out:
# <AxesSubplot:title={'center':'Employers Who Provide Mental Health Benefits'}>

# %%
#1. Analysis of Question 4 - How many employers provide mental health benefits *yearly* breakdown
#come back to how to create yearly data frame when we cant use groupby
#internal note--need to figure out how to group by year without using arithmentic
yearly_employers_who_provide_mental_health_benefits = tech_mental_health.groupby(["YEAR","4_MH_BEN_PROVIDED"]).count()
yearly_employers_who_provide_mental_health_benefits
# Out:
#                                      1_SELF_EMPLOY  2_NUM_OF_EMPLOYEES  \
# YEAR 4_MH_BEN_PROVIDED
# 2017 I don't know                              130                 130
#      No                                         75                  75
#      Not eligible for coverage / NA             18                  18
#      Yes                                       278                 278
# 2018 I don't know                               62                  62
#      No                                         31                  31
#      Not eligible for coverage / NA             16                  16
#      Yes                                       157                 157
# 2020 I don't know                               28                  28
#      No                                         22                  22
#      Not eligible for coverage / NA              6                   6
#      Yes                                        41                  41
#
#                                      3_TECH_ORG  5_AWARE_OF_MH_BENEFITS  \
# YEAR 4_MH_BEN_PROVIDED
# 2017 I don't know                           130                     120
#      No                                      75                      45
#      Not eligible for coverage / NA          18                       4
#      Yes                                    278                     276
# 2018 I don't know                            62                      61
#      No                                      31                      16
#      Not eligible for coverage / NA          16                       3
#      Yes                                    157                     156
# 2020 I don't know                            28                      26
#      No                                      22                      12
#      Not eligible for coverage / NA           6                       4
#      Yes                                     41                      41
#
#                                      6_EMPLOY_FORMALLY_DISCUSS_MH  \
# YEAR 4_MH_BEN_PROVIDED
# 2017 I don't know                                             130
#      No                                                        75
#      Not eligible for coverage / NA                            18
#      Yes                                                      278
# 2018 I don't know                                              62
#      No                                                        31
#      Not eligible for coverage / NA                            16
#      Yes                                                      157
# 2020 I don't know                                              28
#      No                                                        22
#      Not eligible for coverage / NA                             6
#      Yes                                                       41
#
#                                      7_EMPLOY_OFFER_RESOURCES  \
# YEAR 4_MH_BEN_PROVIDED
# 2017 I don't know                                         130
#      No                                                    75
#      Not eligible for coverage / NA                        18
#      Yes                                                  278
# 2018 I don't know                                          62
#      No                                                    31
#      Not eligible for coverage / NA                        16
#      Yes                                                  157
# 2020 I don't know                                          28
#      No                                                    22
#      Not eligible for coverage / NA                         6
#      Yes                                                   41
#
#                                      8_ANONIMITY_PROTECT  \
# YEAR 4_MH_BEN_PROVIDED
# 2017 I don't know                                    130
#      No                                               75
#      Not eligible for coverage / NA                   18
#      Yes                                             278
# 2018 I don't know                                     62
#      No                                               31
#      Not eligible for coverage / NA                   16
#      Yes                                             157
# 2020 I don't know                                     28
#      No                                               22
#      Not eligible for coverage / NA                    6
#      Yes                                              41
#
#                                      9_COMFORT_DISCUSS_SUPERVISOR  \
# YEAR 4_MH_BEN_PROVIDED
# 2017 I don't know                                             130
#      No                                                        75
#      Not eligible for coverage / NA                            18
#      Yes                                                      278
# 2018 I don't know                                              62
#      No                                                        31
#      Not eligible for coverage / NA                            16
#      Yes                                                      157
# 2020 I don't know                                              28
#      No                                                        22
#      Not eligible for coverage / NA                             6
#      Yes                                                       41
#
#                                      10_EVER_DISUSS_MH_w_EMPLOY  \
# YEAR 4_MH_BEN_PROVIDED
# 2017 I don't know                                           130
#      No                                                      75
#      Not eligible for coverage / NA                          18
#      Yes                                                    278
# 2018 I don't know                                            62
#      No                                                      31
#      Not eligible for coverage / NA                          16
#      Yes                                                    157
# 2020 I don't know                                            28
#      No                                                      22
#      Not eligible for coverage / NA                           6
#      Yes                                                     41
#
#                                      11_IMPORTANCE_EMPLOY_PHYS_HEALTH  ...  \
# YEAR 4_MH_BEN_PROVIDED                                                 ...
# 2017 I don't know                                                 130  ...
#      No                                                            75  ...
#      Not eligible for coverage / NA                                18  ...
#      Yes                                                          278  ...
# 2018 I don't know                                                  62  ...
#      No                                                            31  ...
#      Not eligible for coverage / NA                                16  ...
#      Yes                                                          157  ...
# 2020 I don't know                                                  28  ...
#      No                                                            22  ...
#      Not eligible for coverage / NA                                 6  ...
#      Yes                                                           41  ...
#
#                                      16_DIAGNOSED_MH_DISORDER  \
# YEAR 4_MH_BEN_PROVIDED
# 2017 I don't know                                          30
#      No                                                    22
#      Not eligible for coverage / NA                         9
#      Yes                                                  143
# 2018 I don't know                                          18
#      No                                                    12
#      Not eligible for coverage / NA                         5
#      Yes                                                   87
# 2020 I don't know                                           5
#      No                                                     3
#      Not eligible for coverage / NA                         2
#      Yes                                                   15
#
#                                      17_DISORDER_INTERFERE_WITH_WORK_WHEN_TREATED  \
# YEAR 4_MH_BEN_PROVIDED
# 2017 I don't know                                                             130
#      No                                                                        75
#      Not eligible for coverage / NA                                            18
#      Yes                                                                      278
# 2018 I don't know                                                              62
#      No                                                                        31
#      Not eligible for coverage / NA                                            16
#      Yes                                                                      157
# 2020 I don't know                                                              28
#      No                                                                        22
#      Not eligible for coverage / NA                                             6
#      Yes                                                                       41
#
#                                      18_DISORDER_INTERFERE_WITH_WORK_WHEN_NOT_TREATED  \
# YEAR 4_MH_BEN_PROVIDED
# 2017 I don't know                                                                 130
#      No                                                                            75
#      Not eligible for coverage / NA                                                18
#      Yes                                                                          278
# 2018 I don't know                                                                  62
#      No                                                                            31
#      Not eligible for coverage / NA                                                16
#      Yes                                                                          157
# 2020 I don't know                                                                  28
#      No                                                                            22
#      Not eligible for coverage / NA                                                 6
#      Yes                                                                           41
#
#                                      19_TECH_SUPPORT_EMPLOYEE_w_MH_DISORDER  \
# YEAR 4_MH_BEN_PROVIDED
# 2017 I don't know                                                       130
#      No                                                                  75
#      Not eligible for coverage / NA                                      18
#      Yes                                                                278
# 2018 I don't know                                                        62
#      No                                                                  31
#      Not eligible for coverage / NA                                      16
#      Yes                                                                157
# 2020 I don't know                                                        28
#      No                                                                  22
#      Not eligible for coverage / NA                                       6
#      Yes                                                                 41
#
#                                      20_AGE  21_GENDER  22_COUNTRY  23_STATE  \
# YEAR 4_MH_BEN_PROVIDED
# 2017 I don't know                       130        129         130        88
#      No                                  75         75          75        15
#      Not eligible for coverage / NA      18         18          18         6
#      Yes                                278        273         278       237
# 2018 I don't know                        62         62          62        46
#      No                                  31         31          31        12
#      Not eligible for coverage / NA      16         15          16         7
#      Yes                                157        157         157       140
# 2020 I don't know                        28         28          28        10
#      No                                  22         22          22         2
#      Not eligible for coverage / NA       6          6           6         1
#      Yes                                 41         40          41        25
#
#                                      24_RACE  25_COUNTRY_2
# YEAR 4_MH_BEN_PROVIDED
# 2017 I don't know                         85           130
#      No                                   15            75
#      Not eligible for coverage / NA        6            18
#      Yes                                 230           278
# 2018 I don't know                         44            62
#      No                                   12            31
#      Not eligible for coverage / NA        7            16
#      Yes                                 137           157
# 2020 I don't know                         10            28
#      No                                    2            22
#      Not eligible for coverage / NA        1             6
#      Yes                                  24            41
#
# [12 rows x 24 columns]

# %%
#2.Level of comfort people have discussing mental health with employers vs how many people have actually discussed mental health with employers? 
# Main - Stacked bar chart level of comfort disucssing each year
# Main - Stacked bar chart actually disuccsing each year
# TBD if we see higher number of yeses in comfort are high, lets see if we can plot regression of number of yes in comfort vs number of yes in discussion
#stacked bar chart  https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.bar.html

#Level of comfort people have discussing mental health with employers across each year (Question 9) - Stacked Bar Chart

<function matplotlib.pyplot.bar(x, height, width=0.8, bottom=None, *, align='center', data=None, **kwargs)>

# #Bar and Pie Charts using Pandas
​
count_drug_regimen = unique_mice_df["Drug Regimen"].value_counts()
count_drug_regimen_df =count_drug_regimen
count_drug_regimen_df.plot(kind = "bar", title = "Total Measurements per Drug Regimen", xlabel="Drug Regimen", ylabel= "Total Measurements of Drug Regimen")




#Formatting for stacked bar chart
# speed = [0.1, 17.5, 40, 48, 52, 69, 88]
# lifespan = [2, 8, 70, 1.5, 25, 12, 28]
# index = ['snail', 'pig', 'elephant',
#          'rabbit', 'giraffe', 'coyote', 'horse']
# df = pd.DataFrame({'speed': speed,
#                    'lifespan': lifespan}, index=index)
# ax = df.plot.bar(rot=0) 

# ax = df.plot.bar(stacked=True)
# Out:
#   File "<ipython-input-9-362e00edfe83>", line 9
#     <function matplotlib.pyplot.bar(x, height, width=0.8, bottom=None, *, align='center', data=None, **kwargs)>
#     ^
# SyntaxError: invalid syntax

# %%
#2.Level of comfort people have discussing mental health with employers vs how many people have actually discussed mental health with employers? 
#Level of comfort people have discussing mental health with employers across each year (Question 10) - Stacked Bar Chart

# %%
#2.Level of comfort people have discussing mental health with employers vs how many people have actually discussed mental health with employers? 
#Regression TBD

# %%
#3 Do those that have mental disorders in tech ( question 15) feel as though they are supported in the tech industry ( question 19)? 
#Create data frame of those who answer yes to answer 15 (using .loc from the original clean data frame surey_data_df return “Yes” then index by question 19 “level of support”
#Gives us the data frame to work with (Tom)
#note: at aggregate level, not broken down by year

# %%
#3. Do those that have mental disorders in tech (15) feel as though they are supported in the tech industry (19)? 
#Plot pie chart "Percentage of Individuals with mental health disorders that feel supported". No need to bin because range 1-5

# %%
#Do those that have mental disorders in tech (15) feel as though they are supported in the tech industry (19)? 
#Regression TBD

# %%
# #2. Level of comfort people have discussing mental health with employers vs how many people have actually discussed mental health with employers?


# IMPORTANCE_EMPLOY_PHYS_HEALTH= survey_data_df["11_IMPORTANCE_EMPLOY_PHYS_HEALTH"].value_counts()
# IMPORTANCE_EMPLOY_PHYS_HEALTH

# # year_2017_health_type = survey_data_df["Year"] =="2017"
# # result_2017= survey_df.loc[year_2017_health_type]
# # mouse_y793= capomulin_table.loc[capomulin_table["Mouse ID"]=="y793"]
# # plt.plot(mousedata["Timepoint"], mousedata["Tumor Volume (mm3)"])
# # plt.xlabel("Timepoint (days)")
# # plt.ylabel("Tumor Volume (mm3)")
# # plt.title("Capomulin treatment of mouse y793")
# # plt.show()year_2017_health_type

# %%
#TBD - What is the level of importance placed on mental health placed by employers over time?
#Only find values in "12_IMPORTANCE_EMPLOY_MENTAL_HEALTH" > 8
importance_mental_value = tech_mental_health.loc[tech_mental_health["12_IMPORTANCE_EMPLOY_MENTAL_HEALTH"] >= 5 ]
#importance_mental_value

importance_Physical_value = tech_mental_health.loc[tech_mental_health["11_IMPORTANCE_EMPLOY_PHYS_HEALTH"] >= 5 ]
#importance_Physical_value

year = tech_mental_health["YEAR"]
#year
# mental_health = purchase_data_df["Item Name"].count()

importance_value_count_df = pd.DataFrame({"MENTAL HALTH > 5":[importance_mental_value],
                                         "PHYSICAL HEALTH > 5":[importance_Physical_value],
                                         "YEAR":[year],})

importance_value_count_df
# importance_value_count = (importance_value["12_IMPORTANCE_EMPLOY_MENTAL_HEALTH"].count())
# importance_value_count


# importance_mental_by_year = pd.DataFrame(importance_value.groupby('YEAR')['12_IMPORTANCE_EMPLOY_MENTAL_HEALTH']['11_IMPORTANCE_EMPLOY_PHYS_HEALTH'].count().reset_index().rename(columns={'12_IMPORTANCE_EMPLOY_MENTAL_HEALTH': '12 A _IMPORTANCE_EMPLOY_MENTAL_HEALTH'}))
# # pd.options.display.max_columns = 27
# #imp_value_count
# importance_value_by_year





#imp_value.to_csv('Output_CSV/weather_data.csv')

# plt.plot(tech_mental_health["Timepoint"], cap_mouse_1["Tumor Volume (mm3)"], marker = 'x')


# plt.xlabel("TIMEPOINT")
# plt.ylabel("TUMOR VOLUME")
# plt.title("MOUSE L509")
# Out:
#                                     MENTAL HALTH > 5  \
# 0        YEAR 1_SELF_EMPLOY 2_NUM_OF_EMPLOYEES 3_...
#
#                                  PHYSICAL HEALTH > 5  \
# 0        YEAR 1_SELF_EMPLOY 2_NUM_OF_EMPLOYEES 3_...
#
#                                                 YEAR
# 0  0       2017
# 1       2017
# 2       2017
# 3      ...

# %%
#imp_value.to_csv('Output_CSV/weather_data.csv')

plt.plot(imp_value_by_year["YEAR"], imp_value_by_year["12 A _IMPORTANCE_EMPLOY_MENTAL_HEALTH"], marker = 'x')


# plt.xlabel("TIMEPOINT")
# plt.ylabel("TUMOR VOLUME")
# plt.title("MOUSE L509")
