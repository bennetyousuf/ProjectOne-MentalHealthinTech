# %%
#Import Dependencies

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import scipy.stats as st
from scipy.stats import linregress
import time
from datetime import datetime

# %%
#import raw data csv

input_data_file = "../../RAW DATA/SURVEY RAW DATA 2_CSV.CSV"

# Read in file and store in Pandas data frame
survey_data_df = pd.read_csv(input_data_file)
survey_data_df
# Out:
#       YEAR 1_SELF_EMPLOY 2_NUM_OF_EMPLOYEES 3_TECH_ORG  \
# 0     2017             0            100-500          1
# 1     2017             0            100-500          1
# 2     2017             0             25-Jun          1
# 3     2017             0     More than 1000          1
# 4     2017             1                NaN        NaN
# ...    ...           ...                ...        ...
# 1700  2020             0     More than 1000          0
# 1701  2020             0             26-100          1
# 1702  2020             0            100-500          1
# 1703  2020             0           500-1000          0
# 1704  2020             0           500-1000          1
#
#                    4_MH_BEN_PROVIDED 5_AWARE_OF_MH_BENEFITS  \
# 0                                 No                    Yes
# 1                                Yes                    Yes
# 2                       I don't know                     No
# 3                                Yes                    Yes
# 4                                NaN                    NaN
# ...                              ...                    ...
# 1700                              No                     No
# 1701                             Yes                    Yes
# 1702                    I don't know                     No
# 1703                             Yes                     No
# 1704  Not eligible for coverage / NA                    NaN
#
#      6_EMPLOY_FORMALLY_DISCUSS_MH 7_EMPLOY_OFFER_RESOURCES  \
# 0                              No             I don't know
# 1                              No                       No
# 2                    I don't know                       No
# 3                    I don't know             I don't know
# 4                             NaN                      NaN
# ...                           ...                      ...
# 1700                           No                       No
# 1701                          Yes                      Yes
# 1702                           No             I don't know
# 1703                          Yes                      Yes
# 1704                          Yes                       No
#
#      8_ANONIMITY_PROTECT 9_COMFORT_DISCUSS_SUPERVISOR  \
# 0           I don't know                          Yes
# 1           I don't know                        Maybe
# 2                    Yes                          Yes
# 3                    Yes                          Yes
# 4                    NaN                          NaN
# ...                  ...                          ...
# 1700                  No                           No
# 1701        I don't know                        Maybe
# 1702        I don't know                        Maybe
# 1703                 Yes                           No
# 1704        I don't know                          Yes
#
#      10_EVER_DISUSS_MH_w_EMPLOY  11_IMPORTANCE_EMPLOY_PHYS_HEALTH  \
# 0                             0                               6.0
# 1                             0                               7.0
# 2                             1                               0.0
# 3                             1                               7.0
# 4                           NaN                               NaN
# ...                         ...                               ...
# 1700                          0                               2.0
# 1701                          0                               9.0
# 1702                          0                               5.0
# 1703                          0                               6.0
# 1704                          1                               8.0
#
#       12_IMPORTANCE_EMPLOY_MENTAL_HEALTH  \
# 0                                    0.0
# 1                                    2.0
# 2                                    1.0
# 3                                    5.0
# 4                                    NaN
# ...                                  ...
# 1700                                 2.0
# 1701                                 7.0
# 1702                                 5.0
# 1703                                 5.0
# 1704                                 8.0
#
#      13_IF_DIAGNOSED_MH_REVEAL_COWORK_EMPLOYEES  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                 No, because it doesn't matter
# ...                                         ...
# 1700                                        NaN
# 1701                                        NaN
# 1702                                        NaN
# 1703                                        NaN
# 1704                                        NaN
#
#      14_IF_REVEAL_DISORDER_HOW_IMPACT_RELATIONSHIP 15_CURRENT_MH_DISORDER  \
# 0                                              NaN               Possibly
# 1                                              NaN               Possibly
# 2                                              NaN                    Yes
# 3                                              NaN                    Yes
# 4                                        No change                     No
# ...                                            ...                    ...
# 1700                                           NaN                     No
# 1701                                           NaN               Possibly
# 1702                                           NaN                    Yes
# 1703                                           NaN               Possibly
# 1704                                           NaN                     No
#
#      16_DIAGNOSED_MH_DISORDER 17_DISORDER_INTERFERE_WITH_WORK_WHEN_TREATED  \
# 0                         NaN                                    Sometimes
# 1                         NaN                         Not applicable to me
# 2                         Yes                                    Sometimes
# 3                         Yes                                    Sometimes
# 4                         NaN                                        Often
# ...                       ...                                          ...
# 1700                      NaN                                    Sometimes
# 1701                      NaN                                        Often
# 1702                      Yes                                    Sometimes
# 1703                      NaN                                       Rarely
# 1704                      NaN                         Not applicable to me
#
#      18_DISORDER_INTERFERE_WITH_WORK_WHEN_NOT_TREATED  \
# 0                                           Sometimes
# 1                                           Sometimes
# 2                                           Sometimes
# 3                                               Often
# 4                                           Sometimes
# ...                                               ...
# 1700                                            Often
# 1701                                            Often
# 1702                                            Often
# 1703                                        Sometimes
# 1704                             Not applicable to me
#
#       19_TECH_SUPPORT_EMPLOYEE_w_MH_DISORDER  20_AGE 21_GENDER  \
# 0                                        1.0    27.0    Female
# 1                                        2.0    31.0      male
# 2                                        1.0    36.0      male
# 3                                        2.0    22.0      Male
# 4                                        1.0    52.0    female
# ...                                      ...     ...       ...
# 1700                                     2.0    53.0      Male
# 1701                                     3.0    23.0         F
# 1702                                     3.0    34.0      Male
# 1703                                     3.0    43.0      Male
# 1704                                     4.0    37.0      male
#
#                     22_COUNTRY    23_STATE                     24_RACE  \
# 0               United Kingdom         NaN                         NaN
# 1               United Kingdom         NaN                         NaN
# 2     United States of America    Missouri                       White
# 3     United States of America  Washington                       White
# 4     United States of America    Illinois  More than one of the above
# ...                        ...         ...                         ...
# 1700  United States of America    New York                       Asian
# 1701               Philippines         NaN                         NaN
# 1702  United States of America   Tennessee                       White
# 1703                    Canada         NaN                         NaN
# 1704               Netherlands         NaN                         NaN
#
#                   25_COUNTRY_2
# 0               United Kingdom
# 1               United Kingdom
# 2     United States of America
# 3     United States of America
# 4     United States of America
# ...                        ...
# 1700  United States of America
# 1701               Philippines
# 1702  United States of America
# 1703                    Canada
# 1704               Netherlands
#
# [1705 rows x 26 columns]

# %%
# replace "True" and "false" values in CSV to match the rest of the data 
survey_data_df['3_TECH_ORG'].replace('TRUE',"1", inplace=True)
survey_data_df['3_TECH_ORG'].replace('FALSE',"0", inplace=True)

survey_data_df
# Out:
#       YEAR 1_SELF_EMPLOY 2_NUM_OF_EMPLOYEES 3_TECH_ORG  \
# 0     2017             0            100-500          1
# 1     2017             0            100-500          1
# 2     2017             0             25-Jun          1
# 3     2017             0     More than 1000          1
# 4     2017             1                NaN        NaN
# ...    ...           ...                ...        ...
# 1700  2020             0     More than 1000          0
# 1701  2020             0             26-100          1
# 1702  2020             0            100-500          1
# 1703  2020             0           500-1000          0
# 1704  2020             0           500-1000          1
#
#                    4_MH_BEN_PROVIDED 5_AWARE_OF_MH_BENEFITS  \
# 0                                 No                    Yes
# 1                                Yes                    Yes
# 2                       I don't know                     No
# 3                                Yes                    Yes
# 4                                NaN                    NaN
# ...                              ...                    ...
# 1700                              No                     No
# 1701                             Yes                    Yes
# 1702                    I don't know                     No
# 1703                             Yes                     No
# 1704  Not eligible for coverage / NA                    NaN
#
#      6_EMPLOY_FORMALLY_DISCUSS_MH 7_EMPLOY_OFFER_RESOURCES  \
# 0                              No             I don't know
# 1                              No                       No
# 2                    I don't know                       No
# 3                    I don't know             I don't know
# 4                             NaN                      NaN
# ...                           ...                      ...
# 1700                           No                       No
# 1701                          Yes                      Yes
# 1702                           No             I don't know
# 1703                          Yes                      Yes
# 1704                          Yes                       No
#
#      8_ANONIMITY_PROTECT 9_COMFORT_DISCUSS_SUPERVISOR  \
# 0           I don't know                          Yes
# 1           I don't know                        Maybe
# 2                    Yes                          Yes
# 3                    Yes                          Yes
# 4                    NaN                          NaN
# ...                  ...                          ...
# 1700                  No                           No
# 1701        I don't know                        Maybe
# 1702        I don't know                        Maybe
# 1703                 Yes                           No
# 1704        I don't know                          Yes
#
#      10_EVER_DISUSS_MH_w_EMPLOY  11_IMPORTANCE_EMPLOY_PHYS_HEALTH  \
# 0                             0                               6.0
# 1                             0                               7.0
# 2                             1                               0.0
# 3                             1                               7.0
# 4                           NaN                               NaN
# ...                         ...                               ...
# 1700                          0                               2.0
# 1701                          0                               9.0
# 1702                          0                               5.0
# 1703                          0                               6.0
# 1704                          1                               8.0
#
#       12_IMPORTANCE_EMPLOY_MENTAL_HEALTH  \
# 0                                    0.0
# 1                                    2.0
# 2                                    1.0
# 3                                    5.0
# 4                                    NaN
# ...                                  ...
# 1700                                 2.0
# 1701                                 7.0
# 1702                                 5.0
# 1703                                 5.0
# 1704                                 8.0
#
#      13_IF_DIAGNOSED_MH_REVEAL_COWORK_EMPLOYEES  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                 No, because it doesn't matter
# ...                                         ...
# 1700                                        NaN
# 1701                                        NaN
# 1702                                        NaN
# 1703                                        NaN
# 1704                                        NaN
#
#      14_IF_REVEAL_DISORDER_HOW_IMPACT_RELATIONSHIP 15_CURRENT_MH_DISORDER  \
# 0                                              NaN               Possibly
# 1                                              NaN               Possibly
# 2                                              NaN                    Yes
# 3                                              NaN                    Yes
# 4                                        No change                     No
# ...                                            ...                    ...
# 1700                                           NaN                     No
# 1701                                           NaN               Possibly
# 1702                                           NaN                    Yes
# 1703                                           NaN               Possibly
# 1704                                           NaN                     No
#
#      16_DIAGNOSED_MH_DISORDER 17_DISORDER_INTERFERE_WITH_WORK_WHEN_TREATED  \
# 0                         NaN                                    Sometimes
# 1                         NaN                         Not applicable to me
# 2                         Yes                                    Sometimes
# 3                         Yes                                    Sometimes
# 4                         NaN                                        Often
# ...                       ...                                          ...
# 1700                      NaN                                    Sometimes
# 1701                      NaN                                        Often
# 1702                      Yes                                    Sometimes
# 1703                      NaN                                       Rarely
# 1704                      NaN                         Not applicable to me
#
#      18_DISORDER_INTERFERE_WITH_WORK_WHEN_NOT_TREATED  \
# 0                                           Sometimes
# 1                                           Sometimes
# 2                                           Sometimes
# 3                                               Often
# 4                                           Sometimes
# ...                                               ...
# 1700                                            Often
# 1701                                            Often
# 1702                                            Often
# 1703                                        Sometimes
# 1704                             Not applicable to me
#
#       19_TECH_SUPPORT_EMPLOYEE_w_MH_DISORDER  20_AGE 21_GENDER  \
# 0                                        1.0    27.0    Female
# 1                                        2.0    31.0      male
# 2                                        1.0    36.0      male
# 3                                        2.0    22.0      Male
# 4                                        1.0    52.0    female
# ...                                      ...     ...       ...
# 1700                                     2.0    53.0      Male
# 1701                                     3.0    23.0         F
# 1702                                     3.0    34.0      Male
# 1703                                     3.0    43.0      Male
# 1704                                     4.0    37.0      male
#
#                     22_COUNTRY    23_STATE                     24_RACE  \
# 0               United Kingdom         NaN                         NaN
# 1               United Kingdom         NaN                         NaN
# 2     United States of America    Missouri                       White
# 3     United States of America  Washington                       White
# 4     United States of America    Illinois  More than one of the above
# ...                        ...         ...                         ...
# 1700  United States of America    New York                       Asian
# 1701               Philippines         NaN                         NaN
# 1702  United States of America   Tennessee                       White
# 1703                    Canada         NaN                         NaN
# 1704               Netherlands         NaN                         NaN
#
#                   25_COUNTRY_2
# 0               United Kingdom
# 1               United Kingdom
# 2     United States of America
# 3     United States of America
# 4     United States of America
# ...                        ...
# 1700  United States of America
# 1701               Philippines
# 1702  United States of America
# 1703                    Canada
# 1704               Netherlands
#
# [1705 rows x 26 columns]

# %%
#Filter to only include tech workers
tech_mental_health = survey_data_df.loc[survey_data_df["3_TECH_ORG"]=="1"]
pd.options.display.max_columns = 27
tech_mental_health
# Out:
#       YEAR 1_SELF_EMPLOY 2_NUM_OF_EMPLOYEES 3_TECH_ORG  \
# 0     2017             0            100-500          1
# 1     2017             0            100-500          1
# 2     2017             0             25-Jun          1
# 3     2017             0     More than 1000          1
# 5     2017             0            100-500          1
# ...    ...           ...                ...        ...
# 1698  2020             0             26-100          1
# 1699  2020             0     More than 1000          1
# 1701  2020             0             26-100          1
# 1702  2020             0            100-500          1
# 1704  2020             0           500-1000          1
#
#                    4_MH_BEN_PROVIDED 5_AWARE_OF_MH_BENEFITS  \
# 0                                 No                    Yes
# 1                                Yes                    Yes
# 2                       I don't know                     No
# 3                                Yes                    Yes
# 5                                Yes                     No
# ...                              ...                    ...
# 1698                             Yes                    Yes
# 1699                    I don't know                     No
# 1701                             Yes                    Yes
# 1702                    I don't know                     No
# 1704  Not eligible for coverage / NA                    NaN
#
#      6_EMPLOY_FORMALLY_DISCUSS_MH 7_EMPLOY_OFFER_RESOURCES  \
# 0                              No             I don't know
# 1                              No                       No
# 2                    I don't know                       No
# 3                    I don't know             I don't know
# 5                              No             I don't know
# ...                           ...                      ...
# 1698                          Yes                      Yes
# 1699                 I don't know             I don't know
# 1701                          Yes                      Yes
# 1702                           No             I don't know
# 1704                          Yes                       No
#
#      8_ANONIMITY_PROTECT 9_COMFORT_DISCUSS_SUPERVISOR  \
# 0           I don't know                          Yes
# 1           I don't know                        Maybe
# 2                    Yes                          Yes
# 3                    Yes                          Yes
# 5                    Yes                        Maybe
# ...                  ...                          ...
# 1698                  No                           No
# 1699        I don't know                           No
# 1701        I don't know                        Maybe
# 1702        I don't know                        Maybe
# 1704        I don't know                          Yes
#
#      10_EVER_DISUSS_MH_w_EMPLOY  11_IMPORTANCE_EMPLOY_PHYS_HEALTH  \
# 0                             0                               6.0
# 1                             0                               7.0
# 2                             1                               0.0
# 3                             1                               7.0
# 5                             0                               9.0
# ...                         ...                               ...
# 1698                          1                               6.0
# 1699                          0                               8.0
# 1701                          0                               9.0
# 1702                          0                               5.0
# 1704                          1                               8.0
#
#       12_IMPORTANCE_EMPLOY_MENTAL_HEALTH  \
# 0                                    0.0
# 1                                    2.0
# 2                                    1.0
# 3                                    5.0
# 5                                    5.0
# ...                                  ...
# 1698                                 4.0
# 1699                                 3.0
# 1701                                 7.0
# 1702                                 5.0
# 1704                                 8.0
#
#      13_IF_DIAGNOSED_MH_REVEAL_COWORK_EMPLOYEES  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 5                                           NaN
# ...                                         ...
# 1698                                        NaN
# 1699                                        NaN
# 1701                                        NaN
# 1702                                        NaN
# 1704                                        NaN
#
#      14_IF_REVEAL_DISORDER_HOW_IMPACT_RELATIONSHIP 15_CURRENT_MH_DISORDER  \
# 0                                              NaN               Possibly
# 1                                              NaN               Possibly
# 2                                              NaN                    Yes
# 3                                              NaN                    Yes
# 5                                              NaN                     No
# ...                                            ...                    ...
# 1698                                           NaN                    Yes
# 1699                                           NaN                     No
# 1701                                           NaN               Possibly
# 1702                                           NaN                    Yes
# 1704                                           NaN                     No
#
#      16_DIAGNOSED_MH_DISORDER 17_DISORDER_INTERFERE_WITH_WORK_WHEN_TREATED  \
# 0                         NaN                                    Sometimes
# 1                         NaN                         Not applicable to me
# 2                         Yes                                    Sometimes
# 3                         Yes                                    Sometimes
# 5                         NaN                                       Rarely
# ...                       ...                                          ...
# 1698                      Yes                                    Sometimes
# 1699                      NaN                                        Often
# 1701                      NaN                                        Often
# 1702                      Yes                                    Sometimes
# 1704                      NaN                         Not applicable to me
#
#      18_DISORDER_INTERFERE_WITH_WORK_WHEN_NOT_TREATED  \
# 0                                           Sometimes
# 1                                           Sometimes
# 2                                           Sometimes
# 3                                               Often
# 5                                Not applicable to me
# ...                                               ...
# 1698                                            Often
# 1699                                            Often
# 1701                                            Often
# 1702                                            Often
# 1704                             Not applicable to me
#
#       19_TECH_SUPPORT_EMPLOYEE_w_MH_DISORDER  20_AGE 21_GENDER  \
# 0                                        1.0    27.0    Female
# 1                                        2.0    31.0      male
# 2                                        1.0    36.0      male
# 3                                        2.0    22.0      Male
# 5                                        2.0    30.0      male
# ...                                      ...     ...       ...
# 1698                                     2.0    40.0    Female
# 1699                                     2.0    31.0      male
# 1701                                     3.0    23.0         F
# 1702                                     3.0    34.0      Male
# 1704                                     4.0    37.0      male
#
#                     22_COUNTRY    23_STATE 24_RACE              25_COUNTRY_2
# 0               United Kingdom         NaN     NaN            United Kingdom
# 1               United Kingdom         NaN     NaN            United Kingdom
# 2     United States of America    Missouri   White  United States of America
# 3     United States of America  Washington   White  United States of America
# 5     United States of America  California   White  United States of America
# ...                        ...         ...     ...                       ...
# 1698            United Kingdom         NaN     NaN            United Kingdom
# 1699                     India         NaN     NaN                     India
# 1701               Philippines         NaN     NaN               Philippines
# 1702  United States of America   Tennessee   White  United States of America
# 1704               Netherlands         NaN     NaN               Netherlands
#
# [1071 rows x 26 columns]

# %%
# Check total nuber of questions by year for analysis (11 and 12)
tech_mental_health.groupby("YEAR").count()
# Out:
#       1_SELF_EMPLOY  2_NUM_OF_EMPLOYEES  3_TECH_ORG  4_MH_BEN_PROVIDED  \
# YEAR
# 2017            501                 501         501                501
# 2018            266                 266         266                266
# 2019            207                 207         207                207
# 2020             97                  97          97                 97
#
#       5_AWARE_OF_MH_BENEFITS  6_EMPLOY_FORMALLY_DISCUSS_MH  \
# YEAR
# 2017                     445                           501
# 2018                     236                           266
# 2019                     188                           207
# 2020                      83                            97
#
#       7_EMPLOY_OFFER_RESOURCES  8_ANONIMITY_PROTECT  \
# YEAR
# 2017                       501                  501
# 2018                       266                  266
# 2019                       207                  207
# 2020                        97                   97
#
#       9_COMFORT_DISCUSS_SUPERVISOR  10_EVER_DISUSS_MH_w_EMPLOY  \
# YEAR
# 2017                           501                         501
# 2018                           266                         266
# 2019                           207                         207
# 2020                            97                          97
#
#       11_IMPORTANCE_EMPLOY_PHYS_HEALTH  12_IMPORTANCE_EMPLOY_MENTAL_HEALTH  \
# YEAR
# 2017                               501                                 501
# 2018                               266                                 266
# 2019                               207                                 207
# 2020                                97                                  97
#
#       13_IF_DIAGNOSED_MH_REVEAL_COWORK_EMPLOYEES  \
# YEAR
# 2017                                           0
# 2018                                           0
# 2019                                           0
# 2020                                           0
#
#       14_IF_REVEAL_DISORDER_HOW_IMPACT_RELATIONSHIP  15_CURRENT_MH_DISORDER  \
# YEAR
# 2017                                              0                     501
# 2018                                              0                     266
# 2019                                              0                     207
# 2020                                              0                      97
#
#       16_DIAGNOSED_MH_DISORDER  17_DISORDER_INTERFERE_WITH_WORK_WHEN_TREATED  \
# YEAR
# 2017                       204                                           501
# 2018                       122                                           266
# 2019                        86                                           207
# 2020                        25                                            97
#
#       18_DISORDER_INTERFERE_WITH_WORK_WHEN_NOT_TREATED  \
# YEAR
# 2017                                               501
# 2018                                               266
# 2019                                               207
# 2020                                                97
#
#       19_TECH_SUPPORT_EMPLOYEE_w_MH_DISORDER  20_AGE  21_GENDER  22_COUNTRY  \
# YEAR
# 2017                                     501     501        495         501
# 2018                                     266     266        265         266
# 2019                                     207     207        204         207
# 2020                                      97      97         96          97
#
#       23_STATE  24_RACE  25_COUNTRY_2
# YEAR
# 2017       346      336           501
# 2018       205      200           266
# 2019       126      126           207
# 2020        38       37            97

# %%
# 11 and 12 have the same total df for use later 
total_mental_df = pd.DataFrame(tech_mental_health.groupby("YEAR")["12_IMPORTANCE_EMPLOY_MENTAL_HEALTH"].count())
total_mental_df
# Out:
#       12_IMPORTANCE_EMPLOY_MENTAL_HEALTH
# YEAR
# 2017                                 501
# 2018                                 266
# 2019                                 207
# 2020                                  97

# %%
# 11 and 12 have the same total df for use later 
total_physical_df = pd.DataFrame(tech_mental_health.groupby("YEAR")["11_IMPORTANCE_EMPLOY_PHYS_HEALTH"].count())
total_physical_df
# Out:
#       11_IMPORTANCE_EMPLOY_PHYS_HEALTH
# YEAR
# 2017                               501
# 2018                               266
# 2019                               207
# 2020                                97

# %%
#TBD - What is the level of importance placed on mental health placed by employers over time?
#Only find values in "12_IMPORTANCE_EMPLOY_MENTAL_HEALTH" > 5

# Display all columns to check data
pd.options.display.max_columns = 27

# Create DF with Question 12 values >5
importance_mental_value = tech_mental_health.loc[tech_mental_health["12_IMPORTANCE_EMPLOY_MENTAL_HEALTH"] >= 6 ]
importance_mental_value.head(15)
# Out:
#     YEAR 1_SELF_EMPLOY 2_NUM_OF_EMPLOYEES 3_TECH_ORG 4_MH_BEN_PROVIDED  \
# 6   2017             0              44372          1               Yes
# 7   2017             0             26-100          1               Yes
# 12  2017             0     More than 1000          1                No
# 23  2017             0              5-Jan          1                No
# 42  2017             0           500-1000          1               Yes
# 43  2017             0            100-500          1               Yes
# 50  2017             0             25-Jun          1               Yes
# 51  2017             0             25-Jun          1               Yes
# 53  2017             0     More than 1000          1      I don't know
# 57  2017             0            100-500          1               Yes
# 58  2017             0             26-100          1               Yes
# 60  2017             0             26-100          1                No
# 62  2017             0           500-1000          1               Yes
# 66  2017             0             26-100          1               Yes
# 81  2017             0            100-500          1      I don't know
#
#    5_AWARE_OF_MH_BENEFITS 6_EMPLOY_FORMALLY_DISCUSS_MH  \
# 6                     Yes                           No
# 7                      No                           No
# 12                     No                           No
# 23                    NaN                           No
# 42                    Yes                 I don't know
# 43                    Yes                          Yes
# 50                     No                           No
# 51                    Yes                          Yes
# 53                     No                 I don't know
# 57                    Yes                          Yes
# 58                    Yes                          Yes
# 60                    NaN                           No
# 62                    Yes                          Yes
# 66                     No                           No
# 81                    Yes                 I don't know
#
#    7_EMPLOY_OFFER_RESOURCES 8_ANONIMITY_PROTECT 9_COMFORT_DISCUSS_SUPERVISOR  \
# 6                        No                 Yes                          Yes
# 7                        No        I don't know                          Yes
# 12                       No        I don't know                        Maybe
# 23                       No        I don't know                        Maybe
# 42             I don't know        I don't know                        Maybe
# 43                      Yes                 Yes                           No
# 50             I don't know        I don't know                           No
# 51                       No                 Yes                          Yes
# 53             I don't know        I don't know                        Maybe
# 57             I don't know                 Yes                        Maybe
# 58                      Yes        I don't know                          Yes
# 60                      Yes                 Yes                        Maybe
# 62                      Yes        I don't know                          Yes
# 66                       No        I don't know                          Yes
# 81             I don't know        I don't know                          Yes
#
#    10_EVER_DISUSS_MH_w_EMPLOY  11_IMPORTANCE_EMPLOY_PHYS_HEALTH  \
# 6                           0                              10.0
# 7                           0                              10.0
# 12                          1                               7.0
# 23                          1                               6.0
# 42                          0                               9.0
# 43                          0                               8.0
# 50                          0                               6.0
# 51                          1                              10.0
# 53                          0                               8.0
# 57                          0                               7.0
# 58                          1                               9.0
# 60                          0                              10.0
# 62                          1                               5.0
# 66                          1                               9.0
# 81                          0                               9.0
#
#     12_IMPORTANCE_EMPLOY_MENTAL_HEALTH  \
# 6                                 10.0
# 7                                  8.0
# 12                                 7.0
# 23                                 7.0
# 42                                 9.0
# 43                                 8.0
# 50                                 7.0
# 51                                 8.0
# 53                                 7.0
# 57                                 7.0
# 58                                 9.0
# 60                                10.0
# 62                                 6.0
# 66                                 7.0
# 81                                 8.0
#
#    13_IF_DIAGNOSED_MH_REVEAL_COWORK_EMPLOYEES  \
# 6                                         NaN
# 7                                         NaN
# 12                                        NaN
# 23                                        NaN
# 42                                        NaN
# 43                                        NaN
# 50                                        NaN
# 51                                        NaN
# 53                                        NaN
# 57                                        NaN
# 58                                        NaN
# 60                                        NaN
# 62                                        NaN
# 66                                        NaN
# 81                                        NaN
#
#    14_IF_REVEAL_DISORDER_HOW_IMPACT_RELATIONSHIP 15_CURRENT_MH_DISORDER  \
# 6                                            NaN                    Yes
# 7                                            NaN                     No
# 12                                           NaN                     No
# 23                                           NaN                    Yes
# 42                                           NaN                    Yes
# 43                                           NaN               Possibly
# 50                                           NaN                    Yes
# 51                                           NaN                    Yes
# 53                                           NaN             Don't Know
# 57                                           NaN                     No
# 58                                           NaN                    Yes
# 60                                           NaN                    Yes
# 62                                           NaN                    Yes
# 66                                           NaN                    Yes
# 81                                           NaN                    Yes
#
#    16_DIAGNOSED_MH_DISORDER 17_DISORDER_INTERFERE_WITH_WORK_WHEN_TREATED  \
# 6                       Yes                                       Rarely
# 7                       NaN                         Not applicable to me
# 12                      NaN                                    Sometimes
# 23                      Yes                                    Sometimes
# 42                      Yes                                        Never
# 43                      NaN                                        Often
# 50                      Yes                                    Sometimes
# 51                      Yes                                        Often
# 53                      NaN                         Not applicable to me
# 57                      NaN                         Not applicable to me
# 58                      Yes                                    Sometimes
# 60                       No                                        Often
# 62                      Yes                                       Rarely
# 66                      Yes                                        Often
# 81                      Yes                                       Rarely
#
#    18_DISORDER_INTERFERE_WITH_WORK_WHEN_NOT_TREATED  \
# 6                                             Often
# 7                              Not applicable to me
# 12                             Not applicable to me
# 23                                            Often
# 42                                            Often
# 43                                            Often
# 50                                            Often
# 51                                            Often
# 53                             Not applicable to me
# 57                             Not applicable to me
# 58                                            Often
# 60                                            Often
# 62                                           Rarely
# 66                                            Often
# 81                             Not applicable to me
#
#     19_TECH_SUPPORT_EMPLOYEE_w_MH_DISORDER  20_AGE    21_GENDER  \
# 6                                      2.0    36.0            F
# 7                                      2.0    38.0       Female
# 12                                     4.0    23.0         Male
# 23                                     3.0    25.0         Male
# 42                                     4.0    33.0         male
# 43                                     4.0    40.0         Male
# 50                                     3.0    42.0       Female
# 51                                     3.0    37.0  Genderfluid
# 53                                     4.0    47.0         Male
# 57                                     2.0    37.0            M
# 58                                     4.0    30.0       Female
# 60                                     3.0    25.0       Female
# 62                                     3.0    61.0         Male
# 66                                     3.0    26.0       Female
# 81                                     4.0    31.0         Male
#
#                   22_COUNTRY    23_STATE                    24_RACE  \
# 6   United States of America  Washington                      Asian
# 7   United States of America     Georgia                      White
# 12                    Russia         NaN                        NaN
# 23            United Kingdom         NaN                        NaN
# 42  United States of America    Colorado                      White
# 43  United States of America    Virginia  Black or African American
# 50  United States of America    Illinois                      White
# 51                    Canada         NaN                        NaN
# 53            United Kingdom         NaN                        NaN
# 57            United Kingdom         NaN                        NaN
# 58            United Kingdom         NaN                        NaN
# 60            United Kingdom         NaN                        NaN
# 62            United Kingdom         NaN                        NaN
# 66                  Portugal         NaN                        NaN
# 81  United States of America        Utah                      White
#
#                 25_COUNTRY_2
# 6   United States of America
# 7   United States of America
# 12                    Russia
# 23            United Kingdom
# 42  United States of America
# 43  United States of America
# 50  United States of America
# 51                    Canada
# 53            United Kingdom
# 57            United Kingdom
# 58            United Kingdom
# 60            United Kingdom
# 62            United Kingdom
# 66                  Portugal
# 81  United States of America

# %%
# Count total responses for %
#importance_mental_total = importance_mental_value["12_IMPORTANCE_EMPLOY_MENTAL_HEALTH"].count()
#importance_mental_total

# %%
# Create DF with Question 11 values >5
importance_physical_value = tech_mental_health.loc[tech_mental_health["11_IMPORTANCE_EMPLOY_PHYS_HEALTH"] >= 6 ]
importance_physical_value
# Out:
#       YEAR 1_SELF_EMPLOY 2_NUM_OF_EMPLOYEES 3_TECH_ORG  \
# 0     2017             0            100-500          1
# 1     2017             0            100-500          1
# 3     2017             0     More than 1000          1
# 5     2017             0            100-500          1
# 6     2017             0              44372          1
# ...    ...           ...                ...        ...
# 1696  2020             0     More than 1000          1
# 1698  2020             0             26-100          1
# 1699  2020             0     More than 1000          1
# 1701  2020             0             26-100          1
# 1704  2020             0           500-1000          1
#
#                    4_MH_BEN_PROVIDED 5_AWARE_OF_MH_BENEFITS  \
# 0                                 No                    Yes
# 1                                Yes                    Yes
# 3                                Yes                    Yes
# 5                                Yes                     No
# 6                                Yes                    Yes
# ...                              ...                    ...
# 1696                             Yes                    Yes
# 1698                             Yes                    Yes
# 1699                    I don't know                     No
# 1701                             Yes                    Yes
# 1704  Not eligible for coverage / NA                    NaN
#
#      6_EMPLOY_FORMALLY_DISCUSS_MH 7_EMPLOY_OFFER_RESOURCES  \
# 0                              No             I don't know
# 1                              No                       No
# 3                    I don't know             I don't know
# 5                              No             I don't know
# 6                              No                       No
# ...                           ...                      ...
# 1696                          Yes                      Yes
# 1698                          Yes                      Yes
# 1699                 I don't know             I don't know
# 1701                          Yes                      Yes
# 1704                          Yes                       No
#
#      8_ANONIMITY_PROTECT 9_COMFORT_DISCUSS_SUPERVISOR  \
# 0           I don't know                          Yes
# 1           I don't know                        Maybe
# 3                    Yes                          Yes
# 5                    Yes                        Maybe
# 6                    Yes                          Yes
# ...                  ...                          ...
# 1696                 Yes                        Maybe
# 1698                  No                           No
# 1699        I don't know                           No
# 1701        I don't know                        Maybe
# 1704        I don't know                          Yes
#
#      10_EVER_DISUSS_MH_w_EMPLOY  11_IMPORTANCE_EMPLOY_PHYS_HEALTH  \
# 0                             0                               6.0
# 1                             0                               7.0
# 3                             1                               7.0
# 5                             0                               9.0
# 6                             0                              10.0
# ...                         ...                               ...
# 1696                          1                               7.0
# 1698                          1                               6.0
# 1699                          0                               8.0
# 1701                          0                               9.0
# 1704                          1                               8.0
#
#       12_IMPORTANCE_EMPLOY_MENTAL_HEALTH  \
# 0                                    0.0
# 1                                    2.0
# 3                                    5.0
# 5                                    5.0
# 6                                   10.0
# ...                                  ...
# 1696                                 9.0
# 1698                                 4.0
# 1699                                 3.0
# 1701                                 7.0
# 1704                                 8.0
#
#      13_IF_DIAGNOSED_MH_REVEAL_COWORK_EMPLOYEES  \
# 0                                           NaN
# 1                                           NaN
# 3                                           NaN
# 5                                           NaN
# 6                                           NaN
# ...                                         ...
# 1696                                        NaN
# 1698                                        NaN
# 1699                                        NaN
# 1701                                        NaN
# 1704                                        NaN
#
#      14_IF_REVEAL_DISORDER_HOW_IMPACT_RELATIONSHIP 15_CURRENT_MH_DISORDER  \
# 0                                              NaN               Possibly
# 1                                              NaN               Possibly
# 3                                              NaN                    Yes
# 5                                              NaN                     No
# 6                                              NaN                    Yes
# ...                                            ...                    ...
# 1696                                           NaN               Possibly
# 1698                                           NaN                    Yes
# 1699                                           NaN                     No
# 1701                                           NaN               Possibly
# 1704                                           NaN                     No
#
#      16_DIAGNOSED_MH_DISORDER 17_DISORDER_INTERFERE_WITH_WORK_WHEN_TREATED  \
# 0                         NaN                                    Sometimes
# 1                         NaN                         Not applicable to me
# 3                         Yes                                    Sometimes
# 5                         NaN                                       Rarely
# 6                         Yes                                       Rarely
# ...                       ...                                          ...
# 1696                      NaN                         Not applicable to me
# 1698                      Yes                                    Sometimes
# 1699                      NaN                                        Often
# 1701                      NaN                                        Often
# 1704                      NaN                         Not applicable to me
#
#      18_DISORDER_INTERFERE_WITH_WORK_WHEN_NOT_TREATED  \
# 0                                           Sometimes
# 1                                           Sometimes
# 3                                               Often
# 5                                Not applicable to me
# 6                                               Often
# ...                                               ...
# 1696                             Not applicable to me
# 1698                                            Often
# 1699                                            Often
# 1701                                            Often
# 1704                             Not applicable to me
#
#       19_TECH_SUPPORT_EMPLOYEE_w_MH_DISORDER  20_AGE 21_GENDER  \
# 0                                        1.0    27.0    Female
# 1                                        2.0    31.0      male
# 3                                        2.0    22.0      Male
# 5                                        2.0    30.0      male
# 6                                        2.0    36.0         F
# ...                                      ...     ...       ...
# 1696                                     2.0    39.0      Male
# 1698                                     2.0    40.0    Female
# 1699                                     2.0    31.0      male
# 1701                                     3.0    23.0         F
# 1704                                     4.0    37.0      male
#
#                     22_COUNTRY       23_STATE 24_RACE  \
# 0               United Kingdom            NaN     NaN
# 1               United Kingdom            NaN     NaN
# 3     United States of America     Washington   White
# 5     United States of America     California   White
# 6     United States of America     Washington   Asian
# ...                        ...            ...     ...
# 1696  United States of America  Massachusetts   White
# 1698            United Kingdom            NaN     NaN
# 1699                     India            NaN     NaN
# 1701               Philippines            NaN     NaN
# 1704               Netherlands            NaN     NaN
#
#                   25_COUNTRY_2
# 0               United Kingdom
# 1               United Kingdom
# 3     United States of America
# 5     United States of America
# 6     United States of America
# ...                        ...
# 1696  United States of America
# 1698            United Kingdom
# 1699                     India
# 1701               Philippines
# 1704               Netherlands
#
# [701 rows x 26 columns]

# %%
#Create DF of count of MENTAL health values for chart
importance_mental_by_year = pd.DataFrame(importance_mental_value.groupby('YEAR')['12_IMPORTANCE_EMPLOY_MENTAL_HEALTH'].count())
importance_mental_by_year
# Out:
#       12_IMPORTANCE_EMPLOY_MENTAL_HEALTH
# YEAR
# 2017                                 226
# 2018                                 111
# 2019                                  82
# 2020                                  42

# %%
percent_mental_by_year = (importance_mental_by_year / total_mental_df) *100
percent_mental_by_year
# Out:
#       12_IMPORTANCE_EMPLOY_MENTAL_HEALTH
# YEAR
# 2017                           45.109780
# 2018                           41.729323
# 2019                           39.613527
# 2020                           43.298969

# %%
#Create DF of count of PHYSICAL health values for chart
importance_physical_by_year = pd.DataFrame(importance_physical_value.groupby('YEAR')['11_IMPORTANCE_EMPLOY_PHYS_HEALTH'].count())
importance_physical_by_year
# Out:
#       11_IMPORTANCE_EMPLOY_PHYS_HEALTH
# YEAR
# 2017                               334
# 2018                               165
# 2019                               134
# 2020                                68

# %%
percent_phys_by_year = (importance_physical_by_year / total_physical_df) * 100
percent_phys_by_year
# Out:
#       11_IMPORTANCE_EMPLOY_PHYS_HEALTH
# YEAR
# 2017                         66.666667
# 2018                         62.030075
# 2019                         64.734300
# 2020                         70.103093

# %%
#Merge dataset for chart
mental_and_physical_df = pd.merge(importance_mental_by_year, importance_physical_by_year, on='YEAR')
mental_and_physical_df

total_df = pd.merge(mental_and_physical_df,total_physical_df, on="YEAR")
total_df

total_df_1 = pd.merge(total_df,percent_mental_by_year, on="YEAR")
total_df_1 

final_df = pd.merge(total_df_1,percent_phys_by_year, on="YEAR")
final_df
# Out:
#       12_IMPORTANCE_EMPLOY_MENTAL_HEALTH_x  \
# YEAR
# 2017                                   226
# 2018                                   111
# 2019                                    82
# 2020                                    42
#
#       11_IMPORTANCE_EMPLOY_PHYS_HEALTH_x  11_IMPORTANCE_EMPLOY_PHYS_HEALTH_y  \
# YEAR
# 2017                                 334                                 501
# 2018                                 165                                 266
# 2019                                 134                                 207
# 2020                                  68                                  97
#
#       12_IMPORTANCE_EMPLOY_MENTAL_HEALTH_y  11_IMPORTANCE_EMPLOY_PHYS_HEALTH
# YEAR
# 2017                             45.109780                         66.666667
# 2018                             41.729323                         62.030075
# 2019                             39.613527                         64.734300
# 2020                             43.298969                         70.103093

# %%
#imp_value.to_csv('Output_CSV/weather_data.csv')
x_values = ["2017", "2018", "2019", "2020"]
y_value = final_df["12_IMPORTANCE_EMPLOY_MENTAL_HEALTH_y"]
plt.plot(x_values, y_value, marker = 'x')


plt.xlabel("YEAR")
plt.ylabel("% MENTAL HEALTH >5")
plt.title("IMOPRTANCE YOUR EMPLOYER PUTS ON MENTAL HEALTH: RESPONSES  >= 5")
# Out:
# Text(0.5, 1.0, 'IMOPRTANCE YOUR EMPLOYER PUTS ON MENTAL HEALTH: RESPONSES  >= 5')

# %%
y_value_2 = final_df["11_IMPORTANCE_EMPLOY_PHYS_HEALTH"]
plt.plot(x_values, y_value_2, marker = 'x', label = "PHYSICAL HEALTH")


plt.xlabel("YEAR")
plt.ylabel("% PHYSICAL HEALTH >5")
plt.title("IMOPRTANCE YOUR EMPLOYER PUTS ON PHYSICAL HEALTH: RESPONSES >= 5")
plt.legend()

# %%
x_values = ["2017", "2018", "2019", "2020"]

plt.plot(x_values, y_value_2, marker = 'x', label = "PHYSICAL HEALTH")
plt.plot(x_values, y_value, marker = 'o',linestyle = "dashed", label = "MENTAL HEALTH" )
plt.grid(linestyle='-', linewidth=0.5, alpha = 0.5)
plt.xlabel("YEAR")
plt.ylabel("% RESPONSES >= 6")
plt.title("MIND THE GAP!")
plt.legend()
plt.savefig("Images/IMPORTANCE MENTAL VS PHSICAL great equal 6")
plt.show()
